# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhishek0Patil/Assignment16/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()

# %%
from bokeh.plotting import figure , output_file , show
from bokeh.sampledata.iris import flowers

output_file('test.html')

p=figure(title='test flower')
p.xaxis.axis_label = 'petal length '
p.yaxis.axis_label = 'petal width '
p.circle(flowers['petal_length'],flowers['petal_width'])
show(p)
# Out:
#   <div id="ba3d667f-8033-43f2-b153-39fef9726b98" data-root-id="p1001" style="display: contents;"></div>

# %% [markdown]
# Glyphs are visual marks that represent data points on a plot in bokeh plotting

# %%
from bokeh.plotting import figure , output_file , show

output_file('test1.html')

p=figure(title='Glyphs example')
p.xaxis.axis_label = 'X axis '
p.yaxis.axis_label = 'Y axis '
p.circle(x=[1, 2, 3, 4, 5], y=[6, 7, 2, 4, 5], size=20, color="green", alpha=0.5)
show(p)
# Out:
#   <div id="df225ebe-9f3b-4ec1-8a48-cd3c08f00b5d" data-root-id="p1091" style="display: contents;"></div>

# %%
x=[2,3,4,5,6]
y=[3,4,5,6,7]
output_file('line2.html')
p=figure(title = 'line plot')
p.xaxis.axis_label = 'X axis '
p.yaxis.axis_label = 'Y axis '
p.scatter(x,y,color='navy',legend_label='navy points',size=20)
show(p)
# Out:
#   <div id="b9bf1696-f334-4c96-b793-e6d9d7b1376a" data-root-id="p1134" style="display: contents;"></div>

# %% [markdown]
# A Bokeh server is a Python server application that allows for the creation of interactive web-based visualizations with Bokeh that can be updated in real-time.
# To use a Bokeh server to create interactive plots that can be updated in real-time, follow these steps:
#
# 1. Define your Bokeh plot
#
# 2. Import necessary modules
#
# 3. Create a function to generate the plot
#
# 4. Add callbacks
#
# 5. Run the Bokeh server
